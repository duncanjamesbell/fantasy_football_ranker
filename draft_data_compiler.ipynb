# %%
import pandas as pd

# %%
master=pd.read_csv('consolidated_master_revised_2024 20250729.csv')
position_ranks = pd.read_csv('position_ranks_thru_2024.csv')
#build master draft data
draft_file_dir = 'Draft Results/'
draft_data = []
for season in master[master.season>=2012].season.drop_duplicates():
    try:
        draft_df = pd.read_csv(f'{draft_file_dir}{season}.csv')
    except:
        draft_df = pd.read_excel(f'{draft_file_dir}{season}.xlsx')
    if 'Year' not in draft_df.columns:
        draft_df['Year'] = season
    if 'Actual' not in draft_df.columns:
        draft_df['Actual']=''
    if draft_df[['Player','Position']].isnull().sum().sum() > 0:
        print(f'null values found in {season}')
        break
    draft_data.append(draft_df[['Year','Owner','Player','Position','Price','Actual']])

draft_cols_dict = {
    'DST':'DEF',
    'D':'DEF',
    'Def':'DEF'
}
full_draft_df = pd.concat(draft_data)
#full_draft_df=full_draft_df[full_draft_df.Year<2021] #compare to my old numbers
standardized_positions = []
for pos in full_draft_df.Position:
    if pos in draft_cols_dict.keys():
        standardized_positions.append(draft_cols_dict[pos])
    else:
        standardized_positions.append(pos)
full_draft_df['Position'] = standardized_positions
player_name_dict = {}
lkup_player = pd.read_csv('lkup_player.csv')
for index, row in lkup_player.iterrows():
    conc = ''.join([row['Name'],row['Position']])
    if conc not in player_name_dict.keys():
        player_name_dict[conc] = row['Standard Name']

#now add standard name to draft df
standard_players = []
for index, row in full_draft_df.iterrows():
    try:
        player_conc = ''.join([row['Player'],row['Position']])
    except:
        print(row['Player'], row['Position'])
    try:
        standard_players.append(player_name_dict[player_conc])
    except:
        standard_players.append(row['Player'])

full_draft_df['standard_player'] = standard_players

standard_player_concs = []
for index, row in full_draft_df.iterrows():
    standard_player_conc = ''.join([row['standard_player'],row['Position']])
    standard_player_concs.append(standard_player_conc)
full_draft_df['standard_player_conc'] = standard_player_concs

#dictoinary to map defense ids
def_dict = {
    'arizona':'100022',
    'atlanta':'100001',
    'baltimore':'100033',
    'buffalo':'100002',
    'carolina':'100029',
    'chicago':'100003',
    'cincinnati':'100004',
    'cleveland':'100005',
    'dallas':'100006',
    'denver':'100007',
    'detroit':'100008',
    'green-bay':'100009',
    'houston':'100034',
    'indianapolis':'100011',
    'jacksonville':'100030',
    'kansas-city':'100012',
    'la-chargers':'100024',
    'la-rams':'100014',
    'st-louis':'5239',
    'las-vegas':'100013',
    'miami':'100015',
    'minnesota':'100016',
    'new-england':'100017',
    'new-orleans':'100018',
    #ny-giants
    'ny-jets':'100020',
    'philadelphia':'100021',
    'pittsburgh':'100023',
    'san-francisco':'100025',
    'seattle':'100026',
    'tampa-bay':'100027',
    #tennessee
    'washington':'100028'
}

inv_def_dict = {v: k for k, v in def_dict.items()} #probably should stick with the city names

names_dict = pd.read_csv('names_dict.csv')
player_id_dict = {}
for index, row in names_dict.iterrows():
    player_id_dict[row['player_conc']] = row['player_id']

#add player_id column to draft data based on standard player name + position conc
full_draft_df['player_id'] = full_draft_df.standard_player_conc.map(player_id_dict)
full_draft_df.fillna('',inplace=True)
cleaned_player_ids=[]
for i in full_draft_df.player_id:
    try:
        clean_id = str(int(i))
        if clean_id in inv_def_dict.keys():
            clean_id = inv_def_dict[clean_id]
        cleaned_player_ids.append(clean_id)
    except:
        cleaned_player_ids.append('')
full_draft_df['player_id'] = cleaned_player_ids

player_ids = []
for url in position_ranks.player_url:
    split = url.split('/')
    if len(split[-1])>0:
        player_ids.append(str(split[-1]))
    else:
        player_ids.append(str(split[-2]))
position_ranks['player_id'] = player_ids

#get the actual position rank by position, which is the number we really need
position_ranks.sort_values(by=['season','position','position_rank'],ascending=[True,True,True],inplace=True)
actuals =[]
actual_rank=0
#previous_season=position_ranks.iloc[0].season
previous_position=position_ranks.iloc[0].position
for index, row in position_ranks.iterrows():
    if row['position']==previous_position:
        actual_rank=actual_rank+1
    else:
        actual_rank=1
    actuals.append(actual_rank)
    previous_position=row['position']
position_ranks['actual_pos_rank']=actuals

#if this is >0 then some cleanup is required, see notes below for example scenarios
if full_draft_df[~full_draft_df.player_id.isin(list(position_ranks['player_id']))].shape[0] > 0:
    print('There is a problem with missing player_ids in draft_df and/or position_ranks')

#notes
#so what we need to do is append the position ranks into the draft_df.  we hope to do this using player_id.  
#however some do not have player_id for whatever reason.  Some of these can be cleaned, probably by updating standard player names
#but not all.  so I am wondering if we could lkup based on conc of year + name + position?  
#still problem may be that the player simply does not exist in position ranks, which would therefore require manual cleanup 

#FINALLY create position_rank column for full_draft_df - ugh this could have probably been done more efficiently
position_rank_values= []
for index, row in full_draft_df.iterrows():
    if row['Actual'] =='':
        #these are position rank values by yahoo which are questionable...I do not know how they get them but they are different than mine
        position_rank = position_ranks[(position_ranks.player_id == row['player_id']) & (position_ranks.season == row['Year'])].actual_pos_rank.iloc[0]
    else:
        #we prefer this value because it was manually done by me
        position_rank = row['Actual']
    position_rank_values.append(position_rank)

full_draft_df['position_rank'] = position_rank_values

#convert Price to string
int_prices=[]
for price in full_draft_df.Price:
    if type(price)==str:
        price=int(price.replace(',',''))
    int_prices.append(price)
full_draft_df['Price'] = int_prices
full_draft_df.sort_values(by=['Year','Position','Price'],ascending=[True,True,False],inplace=True)
seasons=full_draft_df.Year.drop_duplicates()
season_dfs=[]
for season in seasons:
    position_spend_ranks=[]
    season_draft_df = full_draft_df[full_draft_df.Year==season]
    previous_position=season_draft_df.Position.iloc[0]
    previous_price=season_draft_df.Price.iloc[0]
    previous_spend_rank=1
    player_num=1
    for index, row in season_draft_df.iterrows():
        current_position = row['Position']
        current_price = row['Price']
        if current_position==previous_position:
            if current_price==previous_price:
                current_spend_rank = previous_spend_rank
            else:
                current_spend_rank = player_num
        else:
            current_spend_rank=1
            player_num = 1
        player_num=player_num+1
        position_spend_ranks.append(current_spend_rank)
        previous_position=current_position
        previous_price=current_price
        previous_spend_rank=current_spend_rank
    season_draft_df['spend_rank'] = position_spend_ranks

    #now handle position ranks
    normalized_position_ranks=[]
    season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
    previous_position=season_draft_df.Position.iloc[0]
    previous_pos_rank=season_draft_df.position_rank.iloc[0]
    previous_pos_rank_norm=1
    for index, row in season_draft_df.iterrows():
        current_position = row['Position']
        current_pos_rank=row['position_rank']
        if current_position==previous_position:
            if current_pos_rank==previous_pos_rank:
                current_pos_rank_norm = previous_pos_rank_norm
            else:
                current_pos_rank_norm = previous_pos_rank_norm+1
        else:
            current_pos_rank_norm = 1
        normalized_position_ranks.append(current_pos_rank_norm)
        previous_position=current_position
        previous_pos_rank=current_pos_rank
        previous_pos_rank_norm=current_pos_rank_norm
    season_draft_df['position_rank_normalized'] = normalized_position_ranks
    season_dfs.append(season_draft_df)

#get a dictionary storing count of positions in starting roster for each season, so we can use this to calculcate appropriate bonus points
position_count_dict = {}
for season in full_draft_df.Year.drop_duplicates():
    #print(season)
    matchups_df=pd.read_csv(f'{season}_pre_matchups.csv')
    matchups_df['position']=matchups_df['position'].str.replace(r'\s+', '', regex=True)
    matchup=matchups_df[matchups_df.matchup_url==matchups_df.matchup_url.iloc[0]]
    matchup['positoin'] = matchup['position'].replace(' ','')

    position_counts=matchup.position.value_counts()
    position_dict = {}
    for index, row in pd.DataFrame(position_counts).iterrows():
        position_dict[index] = row['position']
    if 'Q/WR/T' in position_dict:
        position_dict['QB'] = position_dict['QB'] + position_dict['Q/WR/T']
        del position_dict['Q/WR/T']
    if 'W/R/T' in position_dict:
        #we'll count flex as a RB slot for simplicity
        position_dict['RB'] = position_dict['RB'] + position_dict['W/R/T']
        del position_dict['W/R/T']
    
    position_count_dict[season]=position_dict

full_seasons_draft_df=pd.concat(season_dfs)
full_seasons_draft_df['differential'] = full_seasons_draft_df.spend_rank - full_seasons_draft_df.position_rank_normalized
# full_seasons_draft_df['Position']=full_seasons_draft_df.Position.replace(" ",'')
bonus_points=[]
for index, row in full_seasons_draft_df.iterrows():
    number_managers = full_seasons_draft_df[full_seasons_draft_df.Year==row['Year']].Owner.drop_duplicates().shape[0]
    max_bonus = position_count_dict[row['Year']][row['Position']] * number_managers
    bonus=max_bonus-row['position_rank']+1
    if bonus<0:
        bonus=0
    bonus_points.append(bonus)

full_seasons_draft_df['top_pos_bonus'] =bonus_points
full_seasons_draft_df['draft_score'] = full_seasons_draft_df['differential'] + full_seasons_draft_df['top_pos_bonus']

#normalize manager names
manager_name_dict ={
    'Ben':'Benjamin',
    'David':'David Casstevens',
    'Scott':'Scott Gunter',
    'KJ':'Kevin',
    'Pat':'Patrick',
}

normalized_managers=[]
for o in full_seasons_draft_df.Owner:
    if o in manager_name_dict:
        normalized_managers.append(manager_name_dict[o])
    else:
        normalized_managers.append(o)

    
full_seasons_draft_df['owner_normalized'] = normalized_managers

full_seasons_draft_df
# Out:
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['spend_rank'] = position_spend_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df.sort_values(by=['Position','position_rank'],ascending=[True,True],inplace=True)
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_draft_df['position_rank_normalized'] = normalized_position_ranks
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
# C:\Users\dunca\AppData\Local\Temp\ipykernel_16432\1530925642.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matchup['positoin'] = matchup['position'].replace(' ','')
#      Year    Owner          Player Position   Price Actual standard_player  \
# 0    2012   Duncan   Bears Defense      DEF   21000      1         Chicago
# 62   2012     Mark   49ers Defense      DEF  350000      6   San Francisco
# 1    2012     Luke       Houston D      DEF   10000      7         Houston
# 3    2012   Krista         Packers      DEF    1000     14       Green Bay
# 4    2012    Bryan   Lions Defense      DEF   73000     29         Detroit
# ..    ...      ...             ...      ...     ...    ...             ...
# 103  2024  Patrick     Chris Olave       WR      25            Chris Olave
# 127  2024    Bryan  Christian Kirk       WR       5         Christian Kirk
# 115  2024    Bryan     Rashee Rice       WR      13            Rashee Rice
# 116  2024   Duncan   Brandon Aiyuk       WR      13          Brandon Aiyuk
# 135  2024    Scott  Marquise Brown       WR       3         Marquise Brown
#
#     standard_player_conc      player_id  position_rank  spend_rank  \
# 0             ChicagoDEF        chicago            1.0           3
# 62      San FranciscoDEF  san-francisco            6.0           1
# 1             HoustonDEF        houston            7.0           5
# 3           Green BayDEF      green-bay           14.0           6
# 4             DetroitDEF        detroit           29.0           2
# ..                   ...            ...            ...         ...
# 103        Chris OlaveWR          33966           93.0          11
# 127     Christian KirkWR          31017           95.0          32
# 115        Rashee RiceWR          40084           98.0          24
# 116      Brandon AiyukWR          32695          100.0          24
# 135     Marquise BrownWR          31857          145.0          40
#
#      position_rank_normalized  differential  top_pos_bonus  draft_score  \
# 0                           1             2            8.0         10.0
# 62                          2            -1            3.0          2.0
# 1                           3             2            2.0          4.0
# 3                           4             2            0.0          2.0
# 4                           5            -3            0.0         -3.0
# ..                        ...           ...            ...          ...
# 103                        46           -35            0.0        -35.0
# 127                        47           -15            0.0        -15.0
# 115                        48           -24            0.0        -24.0
# 116                        49           -25            0.0        -25.0
# 135                        50           -10            0.0        -10.0
#
#     owner_normalized
# 0             Duncan
# 62              Mark
# 1               Luke
# 3             Krista
# 4              Bryan
# ..               ...
# 103          Patrick
# 127            Bryan
# 115            Bryan
# 116           Duncan
# 135     Scott Gunter
#
# [1651 rows x 16 columns]

# %%
full_seasons_draft_df.Owner.value_counts()
# Out:
# Mark                194
# Luke                180
# Duncan              177
# Krista              172
# Bryan               171
# Patrick             155
# David Casstevens    132
# Scott Gunter        129
# Kevin               124
# Benjamin            104
# David                27
# Scott                26
# KJ                   25
# Ben                  23
# Pat                  12
# Name: Owner, dtype: int64

# %%
full_seasons_draft_df.to_csv('full_seasons_draft_df_20250806.csv',index=False)

# %%
rs = pd.read_csv('all_regular_season_thru_2024.csv')
manager_keys=[]
for m in rs.manager_key:
    manager_keys.append(str(m).split('.')[1])

if '10' not in manager_keys:
    # excel has messed up the trailing 0, sigh, so we need to fix

    print('lala')

rs

# need to correct manager key like .1 -> .10 in all_regular_season_thru_2024
# recommend doing year first then matching on year + manager name from consolidated to get the right manager name....
# Out:
# lala
#        Unnamed: 0 position  manager_id  opponent_id  \
# 0               0       QB           1            2
# 1               1       WR           1            2
# 2               2       WR           1            2
# 3               3       WR           1            2
# 4               4       RB           1            2
# ...           ...      ...         ...          ...
# 19679           5      RB            8            5
# 19680           6      TE            8            5
# 19681           7      WR            8            5
# 19682           8      QB            8            5
# 19683           9     DEF            8            5
#
#                                              matchup_url            player  \
# 0      https://football.fantasysports.yahoo.com//2007...        D. McNabb
# 1      https://football.fantasysports.yahoo.com//2007...      M. Harrison
# 2      https://football.fantasysports.yahoo.com//2007...       C. Johnson
# 3      https://football.fantasysports.yahoo.com//2007...        J. Walker
# 4      https://football.fantasysports.yahoo.com//2007...     L. Tomlinson
# ...                                                  ...               ...
# 19679  https://football.fantasysports.yahoo.com//f1/7...   Aaron Jones Sr.
# 19680  https://football.fantasysports.yahoo.com//f1/7...        Cade Otton
# 19681  https://football.fantasysports.yahoo.com//f1/7...      Elijah Moore
# 19682  https://football.fantasysports.yahoo.com//f1/7...  Matthew Stafford
# 19683  https://football.fantasysports.yahoo.com//f1/7...      Philadelphia
#
#                                              player_url  score  \
# 0             https://sports.yahoo.com/nfl/players/4650   7.00
# 1                              https://sports.yahoo.com  10.00
# 2             https://sports.yahoo.com/nfl/players/5483  10.00
# 3             https://sports.yahoo.com/nfl/players/5906   5.00
# 4             https://sports.yahoo.com/nfl/players/5452  15.00
# ...                                                 ...    ...
# 19679        https://sports.yahoo.com/nfl/players/30295  15.68
# 19680        https://sports.yahoo.com/nfl/players/34062  10.25
# 19681        https://sports.yahoo.com/nfl/players/33422   5.75
# 19682         https://sports.yahoo.com/nfl/players/9265  24.00
# 19683  https://sports.yahoo.com/nfl/teams/philadelphia/  12.00
#
#                         manager  \
# 0          Philadelphia Freedom
# 1          Philadelphia Freedom
# 2          Philadelphia Freedom
# 3          Philadelphia Freedom
# 4          Philadelphia Freedom
# ...                         ...
# 19679  BeepBoopBeep Considering
# 19680  BeepBoopBeep Considering
# 19681  BeepBoopBeep Considering
# 19682  BeepBoopBeep Considering
# 19683  BeepBoopBeep Considering
#
#                                               league_url  league_id  \
# 0      https://football.fantasysports.yahoo.com/2007/...     580505
# 1      https://football.fantasysports.yahoo.com/2007/...     580505
# 2      https://football.fantasysports.yahoo.com/2007/...     580505
# 3      https://football.fantasysports.yahoo.com/2007/...     580505
# 4      https://football.fantasysports.yahoo.com/2007/...     580505
# ...                                                  ...        ...
# 19679  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19680  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19681  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19682  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19683  https://football.fantasysports.yahoo.com/f1/71...     710941
#
#        manager_key
# 0         580505.1
# 1         580505.1
# 2         580505.1
# 3         580505.1
# 4         580505.1
# ...            ...
# 19679     710941.8
# 19680     710941.8
# 19681     710941.8
# 19682     710941.8
# 19683     710941.8
#
# [19684 rows x 12 columns]

# %%
# add is_drafted to regular season file, which we need fo draft/in_season savvy metrics
rs = pd.read_csv('all_regular_season_thru_2024.csv')
consolidated_master = pd.read_csv("consolidated_master_revised_2024_20250729.csv")
current_year='2024'

# add manager names to rs
rs = pd.merge(rs,consolidated_master[['league_id','name','manager']],left_on=['league_id','manager'],right_on=['league_id','name'],how='left')
rs.rename(columns={'manager_x':'manager','manager_y':'manager_name'},inplace=True)

#get player_ids from player_url
player_ids=[]
for url in rs.player_url:
    if isinstance(url,float)==True:
        player_ids.append('')
    else:
        if url[-1] == '/':
            url = url[:-1]
        if '/' not in url:
            player_ids.append('')
        else:
            url = url.split('https://sports.yahoo.com')[1]
            try:
                player_id = url.split('/')[-1]
                player_ids.append(player_id)
            except:
                player_ids.append('')

rs['player_id'] = player_ids

#get year from league url
years=[]
for league_url in rs.league_url:
    if 'com/2' not in league_url:
        years.append(current_year)
    else:
        year = league_url.split('yahoo.com/')[1].split('/')[0]
        years.append(year)

rs['season'] = years

#create conc to match to draft
rs['conc'] = rs['season'] + rs['manager_name'] + rs['player_id']
full_seasons_draft_df['Year'] = full_seasons_draft_df['Year'].astype(str)
full_seasons_draft_df['conc'] = full_seasons_draft_df['Year'] + full_seasons_draft_df['owner_normalized'] + full_seasons_draft_df['player_id']

is_drafted =[]
for conc in rs.conc:
    if conc in full_seasons_draft_df.conc.values:
        is_drafted.append(1)
    else:
        is_drafted.append(0)

rs['is_drafted'] = is_drafted
rs
# Out:
#        Unnamed: 0 position  manager_id  opponent_id  \
# 0               0       QB           1            2
# 1               1       WR           1            2
# 2               2       WR           1            2
# 3               3       WR           1            2
# 4               4       RB           1            2
# ...           ...      ...         ...          ...
# 19679           5      RB            8            5
# 19680           6      TE            8            5
# 19681           7      WR            8            5
# 19682           8      QB            8            5
# 19683           9     DEF            8            5
#
#                                              matchup_url            player  \
# 0      https://football.fantasysports.yahoo.com//2007...        D. McNabb
# 1      https://football.fantasysports.yahoo.com//2007...      M. Harrison
# 2      https://football.fantasysports.yahoo.com//2007...       C. Johnson
# 3      https://football.fantasysports.yahoo.com//2007...        J. Walker
# 4      https://football.fantasysports.yahoo.com//2007...     L. Tomlinson
# ...                                                  ...               ...
# 19679  https://football.fantasysports.yahoo.com//f1/7...   Aaron Jones Sr.
# 19680  https://football.fantasysports.yahoo.com//f1/7...        Cade Otton
# 19681  https://football.fantasysports.yahoo.com//f1/7...      Elijah Moore
# 19682  https://football.fantasysports.yahoo.com//f1/7...  Matthew Stafford
# 19683  https://football.fantasysports.yahoo.com//f1/7...      Philadelphia
#
#                                              player_url  score  \
# 0             https://sports.yahoo.com/nfl/players/4650   7.00
# 1                              https://sports.yahoo.com  10.00
# 2             https://sports.yahoo.com/nfl/players/5483  10.00
# 3             https://sports.yahoo.com/nfl/players/5906   5.00
# 4             https://sports.yahoo.com/nfl/players/5452  15.00
# ...                                                 ...    ...
# 19679        https://sports.yahoo.com/nfl/players/30295  15.68
# 19680        https://sports.yahoo.com/nfl/players/34062  10.25
# 19681        https://sports.yahoo.com/nfl/players/33422   5.75
# 19682         https://sports.yahoo.com/nfl/players/9265  24.00
# 19683  https://sports.yahoo.com/nfl/teams/philadelphia/  12.00
#
#                         manager  \
# 0          Philadelphia Freedom
# 1          Philadelphia Freedom
# 2          Philadelphia Freedom
# 3          Philadelphia Freedom
# 4          Philadelphia Freedom
# ...                         ...
# 19679  BeepBoopBeep Considering
# 19680  BeepBoopBeep Considering
# 19681  BeepBoopBeep Considering
# 19682  BeepBoopBeep Considering
# 19683  BeepBoopBeep Considering
#
#                                               league_url  league_id  \
# 0      https://football.fantasysports.yahoo.com/2007/...     580505
# 1      https://football.fantasysports.yahoo.com/2007/...     580505
# 2      https://football.fantasysports.yahoo.com/2007/...     580505
# 3      https://football.fantasysports.yahoo.com/2007/...     580505
# 4      https://football.fantasysports.yahoo.com/2007/...     580505
# ...                                                  ...        ...
# 19679  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19680  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19681  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19682  https://football.fantasysports.yahoo.com/f1/71...     710941
# 19683  https://football.fantasysports.yahoo.com/f1/71...     710941
#
#        manager_key                      name manager_name     player_id  \
# 0         580505.1      Philadelphia Freedom         Ryan          4650
# 1         580505.1      Philadelphia Freedom         Ryan
# 2         580505.1      Philadelphia Freedom         Ryan          5483
# 3         580505.1      Philadelphia Freedom         Ryan          5906
# 4         580505.1      Philadelphia Freedom         Ryan          5452
# ...            ...                       ...          ...           ...
# 19679     710941.8  BeepBoopBeep Considering       Duncan         30295
# 19680     710941.8  BeepBoopBeep Considering       Duncan         34062
# 19681     710941.8  BeepBoopBeep Considering       Duncan         33422
# 19682     710941.8  BeepBoopBeep Considering       Duncan          9265
# 19683     710941.8  BeepBoopBeep Considering       Duncan  philadelphia
#
#       season                    conc  is_drafted
# 0       2007            2007Ryan4650           0
# 1       2007                2007Ryan           0
# 2       2007            2007Ryan5483           0
# 3       2007            2007Ryan5906           0
# 4       2007            2007Ryan5452           0
# ...      ...                     ...         ...
# 19679   2024         2024Duncan30295           1
# 19680   2024         2024Duncan34062           0
# 19681   2024         2024Duncan33422           0
# 19682   2024          2024Duncan9265           1
# 19683   2024  2024Duncanphiladelphia           0
#
# [19684 rows x 18 columns]

# %%
full_seasons_draft_df.to_csv('full_seasons_draft_df_w_conc_20250806.csv',index=False)
rs.to_csv('all_regular_season_thru_2024_w_is_drafted.csv',index=False)

# %%
rs = pd.read_csv('all_regular_season_thru_2024.csv')
if

# %%
consolidated_master[['manager_key','manager']]
# Out:
#      manager_key           manager
# 0       580505.3           Patrick
# 1       580505.6            Duncan
# 2       580505.2              Luke
# 3       580505.5             Kevin
# 4       580505.1              Ryan
# ..           ...               ...
# 151     710941.4              Mark
# 152     710941.3             Kevin
# 153     710941.9             Bryan
# 154     710941.2           Patrick
# 155     710941.7  David Casstevens
#
# [156 rows x 2 columns]

# %%
for season in full_seasons_draft_df.Year.drop_duplicates():
    season_draft=full_seasons_draft_df[full_seasons_draft_df.Year==season]
    avg_score=season_draft.draft_score.sum() / season_draft.shape[0]
    print(f'{season}: {avg_score}')
# Out:
# 2012: 4.697916666666667
# 2013: 3.83
# 2014: 5.1138211382113825
# 2015: 5.513761467889908
# 2016: 5.417322834645669
# 2017: 5.503875968992248
# 2018: 6.375
# 2019: 6.048275862068966
# 2020: 5.787234042553192
# 2021: 5.946969696969697
# 2022: 8.094890510948906
# 2023: 6.649253731343284
# 2024: 6.725352112676056
